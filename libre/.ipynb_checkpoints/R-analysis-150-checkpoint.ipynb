# %%
library(tidyverse)  # data manipulation
library(cluster)    # clustering algorithms
library(factoextra) # clustering algorithms & visualization
library(dtwclust)
library(lubridate)
library("RColorBrewer")

# %% [markdown]
# ## Dtwclust

# %% [markdown]
# ### Compute CVI & Compare

# %%
types<-c("partitional", "hierarchical", "tadpole","fuzzy")
dists<-c("dtw_lb","lbk","lbi","sbd","gak","sdtw")
for (file in list.files('./datasets2')){
    print(file)
    for (dist in dists){
        df <- read_csv(file.path('./datasets2/',file))
        pc <- tsclust(df, type = "partitional", k = 3L:7L, 
                   distance = dist, centroid = "pam", 
                   seed = 3247L, trace = TRUE, args = tsclust_args(dist = list(window.size = 5L)))
        names(pc) <-paste0("k_", 3L:7L)
        pc_cvi<-sapply(pc,cvi, type="internal")
        print(pc_cvi)
        write.csv(pc_cvi, paste0('cvi/partitional/',dist,'/',file))
        df <- NULL
        pc <- NULL
        pc_cvi <-NULL
    }
}
# Out:
# [1] "90_0.25.csv"
# Parsed with column specification:
# cols(
#   `0` = col_double(),
#   `1` = col_double(),
#   `2` = col_double(),
#   `3` = col_double(),
#   `4` = col_double(),
#   `5` = col_double(),
#   `6` = col_double()
# )
# Warning message in pam_distmat(series, control, distance, cent_char, family, args, :
# “Using dtw_lb with control$pam.precompute = TRUE is not advised.”
# 	Precomputing distance matrix...
# Repetition 1 for k = 3
# Iteration 1: Changes / Distsum = 20749 / 188612.4
# Iteration 2: Changes / Distsum = 1369 / 138454.6
# Iteration 3: Changes / Distsum = 873 / 140748.5
# Iteration 4: Changes / Distsum = 372 / 141480.7
# Iteration 5: Changes / Distsum = 411 / 140159.9
# Iteration 6: Changes / Distsum = 144 / 136120.7
# Iteration 7: Changes / Distsum = 0 / 136120.7
# Repetition 1 for k = 4
# Iteration 1: Changes / Distsum = 20749 / 202200.5
# Iteration 2: Changes / Distsum = 1563 / 127218.1
# Iteration 3: Changes / Distsum = 917 / 124193.1
# Iteration 4: Changes / Distsum = 1062 / 119409.4
# Iteration 5: Changes / Distsum = 289 / 117648.2
# Iteration 6: Changes / Distsum = 0 / 117648.2
# Repetition 1 for k = 5
# Iteration 1: Changes / Distsum = 20749 / 257019
# Iteration 2: Changes / Distsum = 3995 / 140515.2
# Iteration 3: Changes / Distsum = 2789 / 116267.2
# Iteration 4: Changes / Distsum = 1141 / 119732
# Iteration 5: Changes / Distsum = 1817 / 103649.6
# Iteration 6: Changes / Distsum = 685 / 105408.6
# Iteration 7: Changes / Distsum = 666 / 102536.5
# Iteration 8: Changes / Distsum = 301 / 99336.9
# Iteration 9: Changes / Distsum =  0 / 99336.9
# Repetition 1 for k = 6
# Iteration 1: Changes / Distsum = 20749 / 179045.9
# Iteration 2: Changes / Distsum = 5013 / 123767
# Iteration 3: Changes / Distsum = 2468 / 97687.7
# Iteration 4: Changes / Distsum = 1071 / 91758
# Iteration 5: Changes / Distsum = 93 / 92151.7
# Iteration 6: Changes / Distsum =  0 / 92151.7
# Repetition 1 for k = 7
# Iteration 1: Changes / Distsum = 20749 / 111695.4
# Iteration 2: Changes / Distsum = 2518 / 86013.5
# Iteration 3: Changes / Distsum = 916 / 83839.3
# Iteration 4: Changes / Distsum = 1372 / 81347.4
# Iteration 5: Changes / Distsum = 1602 / 78480.5
# Iteration 6: Changes / Distsum = 271 / 78172.1
# Iteration 7: Changes / Distsum = 903 / 76968.7
# Iteration 8: Changes / Distsum = 501 / 76452.1
# Iteration 9: Changes / Distsum = 231 / 76128.1
# Iteration 10: Changes / Distsum =  0 / 76128.1
#
# 	Elapsed time is 53.65 seconds.
# Warning message in FUN(X[[i]], ...):
# “Internal CVIs: series' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	Sil	D	COP”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: centroids' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	DB	DB*”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: series' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	Sil	D	COP”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: centroids' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	DB	DB*”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: series' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	Sil	D	COP”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: centroids' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	DB	DB*”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: series' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	Sil	D	COP”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: centroids' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	DB	DB*”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: series' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	Sil	D	COP”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: centroids' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	DB	DB*”
#                 k_3          k_4          k_5          k_6          k_7
# Sil    5.016655e-01 4.963421e-01 4.054843e-01 4.251223e-01 4.043845e-01
# SF     2.697348e-06 4.336997e-09 1.777390e-08 4.629852e-12 1.027844e-11
# CH     3.639756e+04 3.057635e+04 2.866996e+04 2.407598e+04 2.739196e+04
# DB     5.146771e-01 5.234258e-01 7.356777e-01 1.133585e+00 7.569292e-01
# DBstar 5.972873e-01 6.108579e-01 1.443721e+00 1.729941e+00 1.312338e+00
# D      0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00
# COP    9.441678e-02 6.109280e-02 6.828555e-02 4.478612e-02 4.043054e-02
# Parsed with column specification:
# cols(
#   `0` = col_double(),
#   `1` = col_double(),
#   `2` = col_double(),
#   `3` = col_double(),
#   `4` = col_double(),
#   `5` = col_double(),
#   `6` = col_double()
# )
# 	Precomputing distance matrix...
# Repetition 1 for k = 3
# Iteration 1: Changes / Distsum = 20749 / 133110.5
# Iteration 2: Changes / Distsum = 805 / 199488.8
# Iteration 3: Changes / Distsum = 313 / 198237.2
# Iteration 4: Changes / Distsum = 98 / 201244.4
# Iteration 5: Changes / Distsum = 0 / 201244.4
# Repetition 1 for k = 4
# Iteration 1: Changes / Distsum = 20749 / 47750.7
# Iteration 2: Changes / Distsum = 2520 / 192707.5
# Iteration 3: Changes / Distsum = 1441 / 182951.5
# Iteration 4: Changes / Distsum = 963 / 172743.3
# Iteration 5: Changes / Distsum = 595 / 174747.4
# Iteration 6: Changes / Distsum = 540 / 174186.6
# Iteration 7: Changes / Distsum = 359 / 170250.4
# Iteration 8: Changes / Distsum = 582 / 166232.5
# Iteration 9: Changes / Distsum = 469 / 173456.3
# Iteration 10: Changes / Distsum = 190 / 174637.9
# Iteration 11: Changes / Distsum = 408 / 171298.8
# Iteration 12: Changes / Distsum = 558 / 176408.4
# Iteration 13: Changes / Distsum = 207 / 172173.7
# Iteration 14: Changes / Distsum = 166 / 173621.4
# Iteration 15: Changes / Distsum = 472 / 168953.4
# Iteration 16: Changes / Distsum = 178 / 169352.4
# Iteration 17: Changes / Distsum =  74 / 171232
# Iteration 18: Changes / Distsum = 151 / 171181.6
# Iteration 19: Changes / Distsum = 0 / 171181.6
# Repetition 1 for k = 5
# Iteration 1: Changes / Distsum = 20749 / 89835
# Iteration 2: Changes / Distsum = 13978 / 158615.6
# Iteration 3: Changes / Distsum = 6877 / 210372.2
# Iteration 4: Changes / Distsum = 1678 / 157636.7
# Iteration 5: Changes / Distsum = 763 / 159291.5
# Iteration 6: Changes / Distsum = 452 / 151542.4
# Iteration 7: Changes / Distsum = 552 / 153013.3
# Iteration 8: Changes / Distsum = 612 / 155453.2
# Iteration 9: Changes / Distsum = 179 / 155573.5
# Iteration 10: Changes / Distsum =  53 / 153895
# Iteration 11: Changes / Distsum =   0 / 153895
# Repetition 1 for k = 6
# Iteration 1: Changes / Distsum = 20749 / 55837.7
# Iteration 2: Changes / Distsum = 8503 / 162700.6
# Iteration 3: Changes / Distsum = 2376 / 149094.6
# Iteration 4: Changes / Distsum = 1270 / 146621
# Iteration 5: Changes / Distsum = 802 / 145000.3
# Iteration 6: Changes / Distsum = 766 / 142172.9
# Iteration 7: Changes / Distsum = 770 / 144938
# Iteration 8: Changes / Distsum = 436 / 141387.8
# Iteration 9: Changes / Distsum = 912 / 141917.6
# Iteration 10: Changes / Distsum = 354 / 140909.8
# Iteration 11: Changes / Distsum = 701 / 137860.1
# Iteration 12: Changes / Distsum =  93 / 138402
# Iteration 13: Changes / Distsum =   0 / 138402
# Repetition 1 for k = 7
# Iteration 1: Changes / Distsum = 20749 / 61057.7
# Iteration 2: Changes / Distsum = 3738 / 143552.9
# Iteration 3: Changes / Distsum = 2695 / 137158.2
# Iteration 4: Changes / Distsum = 1286 / 135292.9
# Iteration 5: Changes / Distsum = 604 / 133241.5
# Iteration 6: Changes / Distsum = 909 / 134299.6
# Iteration 7: Changes / Distsum = 584 / 135112.5
# Iteration 8: Changes / Distsum = 196 / 136185.2
# Iteration 9: Changes / Distsum = 665 / 132575.8
# Iteration 10: Changes / Distsum = 151 / 131139.2
# Iteration 11: Changes / Distsum = 301 / 132721.8
# Iteration 12: Changes / Distsum = 0 / 132721.8
#
# 	Elapsed time is 58.852 seconds.
# Warning message in FUN(X[[i]], ...):
# “Internal CVIs: series' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	Sil	D	COP”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: centroids' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	DB	DB*”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: series' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	Sil	D	COP”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: centroids' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	DB	DB*”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: series' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	Sil	D	COP”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: centroids' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	DB	DB*”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: series' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	Sil	D	COP”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: centroids' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	DB	DB*”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: series' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	Sil	D	COP”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: centroids' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	DB	DB*”
#                 k_3          k_4          k_5          k_6          k_7
# Sil    5.538669e-01 5.163637e-01 4.710336e-01 4.588358e-01 4.241992e-01
# SF     1.860312e-11 3.508305e-14 2.442491e-15 0.000000e+00 0.000000e+00
# CH     1.854780e+04 1.518533e+04 1.290871e+04 1.195845e+04 1.041399e+04
# DB     6.985445e-01 7.468546e-01 7.856859e-01 8.547077e-01 9.190775e-01
# DBstar 8.282089e-01 9.604631e-01 1.110233e+00 1.212613e+00 1.333384e+00
# D      0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00
# COP    4.846801e-01 3.808378e-01 3.065762e-01 1.932313e-01 1.679095e-01
# Parsed with column specification:
# cols(
#   `0` = col_double(),
#   `1` = col_double(),
#   `2` = col_double(),
#   `3` = col_double(),
#   `4` = col_double(),
#   `5` = col_double(),
#   `6` = col_double()
# )
# 	Precomputing distance matrix...
# Repetition 1 for k = 3
# Iteration 1: Changes / Distsum = 20749 / 188612.4
# Iteration 2: Changes / Distsum = 1369 / 138454.6
# Iteration 3: Changes / Distsum = 873 / 140748.5
# Iteration 4: Changes / Distsum = 372 / 141480.7
# Iteration 5: Changes / Distsum = 411 / 140159.9
# Iteration 6: Changes / Distsum = 144 / 136120.7
# Iteration 7: Changes / Distsum = 0 / 136120.7
# Repetition 1 for k = 4
# Iteration 1: Changes / Distsum = 20749 / 202200.5
# Iteration 2: Changes / Distsum = 1563 / 127218.1
# Iteration 3: Changes / Distsum = 917 / 124193.1
# Iteration 4: Changes / Distsum = 1062 / 119409.4
# Iteration 5: Changes / Distsum = 289 / 117648.2
# Iteration 6: Changes / Distsum = 0 / 117648.2
# Repetition 1 for k = 5
# Iteration 1: Changes / Distsum = 20749 / 257019
# Iteration 2: Changes / Distsum = 3995 / 140515.2
# Iteration 3: Changes / Distsum = 2789 / 116267.2
# Iteration 4: Changes / Distsum = 1141 / 119732
# Iteration 5: Changes / Distsum = 1817 / 103649.6
# Iteration 6: Changes / Distsum = 685 / 105408.6
# Iteration 7: Changes / Distsum = 666 / 102536.5
# Iteration 8: Changes / Distsum = 301 / 99336.9
# Iteration 9: Changes / Distsum =  0 / 99336.9
# Repetition 1 for k = 6
# Iteration 1: Changes / Distsum = 20749 / 179045.9
# Iteration 2: Changes / Distsum = 5013 / 123767
# Iteration 3: Changes / Distsum = 2468 / 97687.7
# Iteration 4: Changes / Distsum = 1071 / 91758
# Iteration 5: Changes / Distsum = 93 / 92151.7
# Iteration 6: Changes / Distsum =  0 / 92151.7
# Repetition 1 for k = 7
# Iteration 1: Changes / Distsum = 20749 / 111695.4
# Iteration 2: Changes / Distsum = 2518 / 86013.5
# Iteration 3: Changes / Distsum = 916 / 83839.3
# Iteration 4: Changes / Distsum = 1372 / 81347.4
# Iteration 5: Changes / Distsum = 1602 / 78480.5
# Iteration 6: Changes / Distsum = 271 / 78172.1
# Iteration 7: Changes / Distsum = 903 / 76968.7
# Iteration 8: Changes / Distsum = 501 / 76452.1
# Iteration 9: Changes / Distsum = 231 / 76128.1
# Iteration 10: Changes / Distsum =  0 / 76128.1
#
# 	Elapsed time is 43.599 seconds.
# Warning message in FUN(X[[i]], ...):
# “Internal CVIs: series' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	Sil	D	COP”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: centroids' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	DB	DB*”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: series' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	Sil	D	COP”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: centroids' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	DB	DB*”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: series' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	Sil	D	COP”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: centroids' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	DB	DB*”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: series' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	Sil	D	COP”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: centroids' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	DB	DB*”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: series' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	Sil	D	COP”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: centroids' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	DB	DB*”
#                 k_3          k_4          k_5          k_6          k_7
# Sil    5.016655e-01 4.963421e-01 4.054843e-01 4.251223e-01 4.043845e-01
# SF     2.318001e-07 5.651901e-10 2.129032e-09 1.001865e-12 1.943778e-12
# CH     2.475630e+04 2.063557e+04 1.717658e+04 1.549698e+04 1.640768e+04
# DB     5.146771e-01 5.234258e-01 7.356777e-01 1.133585e+00 7.569292e-01
# DBstar 5.972873e-01 6.108579e-01 1.443721e+00 1.729941e+00 1.312338e+00
# D      0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00
# COP    9.441678e-02 6.109280e-02 6.828555e-02 4.478612e-02 4.043054e-02
# Parsed with column specification:
# cols(
#   `0` = col_double(),
#   `1` = col_double(),
#   `2` = col_double(),
#   `3` = col_double(),
#   `4` = col_double(),
#   `5` = col_double(),
#   `6` = col_double()
# )
# 	Precomputing distance matrix...
# Repetition 1 for k = 3
# Iteration 1: Changes / Distsum = 20749 / 130.9183
# Iteration 2: Changes / Distsum = 4654 / 93.23432
# Iteration 3: Changes / Distsum = 2568 / 82.23908
# Iteration 4: Changes / Distsum = 1260 / 78.29728
# Iteration 5: Changes / Distsum = 880 / 76.9254
# Iteration 6: Changes / Distsum = 289 / 76.54321
# Iteration 7: Changes / Distsum = 413 / 76.27493
# Iteration 8: Changes / Distsum = 351 / 76.03281
# Iteration 9: Changes / Distsum = 304 / 75.7291
# Iteration 10: Changes / Distsum =  0 / 75.7291
# Repetition 1 for k = 4
# Iteration 1: Changes / Distsum = 20749 / 71.53091
# Iteration 2: Changes / Distsum = 1076 / 64.2361
# Iteration 3: Changes / Distsum = 627 / 63.35146
# Iteration 4: Changes / Distsum = 575 / 62.85675
# Iteration 5: Changes / Distsum = 156 / 62.82135
# Iteration 6: Changes / Distsum = 309 / 62.75239
# Iteration 7: Changes / Distsum = 370 / 62.64122
# Iteration 8: Changes / Distsum = 0 / 62.64122
# Repetition 1 for k = 5
# Iteration 1: Changes / Distsum = 20749 / 81.25449
# Iteration 2: Changes / Distsum = 2355 / 58.55244
# Iteration 3: Changes / Distsum = 1234 / 56.6812
# Iteration 4: Changes / Distsum = 612 / 56.13617
# Iteration 5: Changes / Distsum = 526 / 55.69973
# Iteration 6: Changes / Distsum = 293 / 55.61267
# Iteration 7: Changes / Distsum = 0 / 55.61267
# Repetition 1 for k = 6
# Iteration 1: Changes / Distsum = 20749 / 111.2448
# Iteration 2: Changes / Distsum = 4262 / 70.26367
# Iteration 3: Changes / Distsum = 3012 / 63.51901
# Iteration 4: Changes / Distsum = 2125 / 59.11487
# Iteration 5: Changes / Distsum = 1377 / 56.84199
# Iteration 6: Changes / Distsum = 1151 / 55.53778
# Iteration 7: Changes / Distsum = 981 / 54.53929
# Iteration 8: Changes / Distsum = 855 / 54.00352
# Iteration 9: Changes / Distsum = 1005 / 53.23045
# Iteration 10: Changes / Distsum = 708 / 52.8862
# Iteration 11: Changes / Distsum = 749 / 52.57275
# Iteration 12: Changes / Distsum = 0 / 52.57275
# Repetition 1 for k = 7
# Iteration 1: Changes / Distsum = 20749 / 102.3879
# Iteration 2: Changes / Distsum = 4348 / 59.00068
# Iteration 3: Changes / Distsum = 2206 / 51.61952
# Iteration 4: Changes / Distsum = 1289 / 48.82776
# Iteration 5: Changes / Distsum = 1058 / 47.89004
# Iteration 6: Changes / Distsum = 399 / 47.50761
# Iteration 7: Changes / Distsum = 618 / 47.0237
# Iteration 8: Changes / Distsum = 601 / 46.75281
# Iteration 9: Changes / Distsum = 480 / 46.60536
# Iteration 10: Changes / Distsum = 404 / 46.43463
# Iteration 11: Changes / Distsum = 0 / 46.43463
#
# 	Elapsed time is 77.119 seconds.
#
#                 k_3          k_4          k_5          k_6          k_7
# Sil    5.732013e-01 4.420574e-01 4.162735e-01 4.048368e-01 4.142955e-01
# SF     6.274934e-01 6.265788e-01 6.255638e-01 6.246217e-01 6.237415e-01
# CH     1.499448e+04 1.353585e+04 1.220379e+04 1.049096e+04 1.014899e+04
# DB     5.875055e-01 7.384324e-01 7.856203e-01 8.607587e-01 8.761361e-01
# DBstar 7.921743e-01 1.432691e+00 1.536017e+00 1.803206e+00 1.723036e+00
# D      4.458894e-05 3.891214e-07 2.777277e-05 1.465021e-05 2.014802e-05
# COP    2.124712e-02 1.697025e-02 1.478395e-02 1.393957e-02 1.171773e-02
# Parsed with column specification:
# cols(
#   `0` = col_double(),
#   `1` = col_double(),
#   `2` = col_double(),
#   `3` = col_double(),
#   `4` = col_double(),
#   `5` = col_double(),
#   `6` = col_double()
# )
# 	Precomputing distance matrix...
# Repetition 1 for k = 3
# Iteration 1: Changes / Distsum = 20749 / 1138.303
# Iteration 2: Changes / Distsum = 1387 / 905.0826
# Iteration 3: Changes / Distsum = 423 / 889.7706
# Iteration 4: Changes / Distsum = 266 / 886.5526
# Iteration 5: Changes / Distsum = 303 / 884.9062
# Iteration 6: Changes / Distsum = 176 / 883.8939
# Iteration 7: Changes / Distsum = 116 / 883.2824
# Iteration 8: Changes / Distsum = 0 / 883.2824
# Repetition 1 for k = 4
# Iteration 1: Changes / Distsum = 20749 / 1522.017
# Iteration 2: Changes / Distsum = 1966 / 803.2895
# Iteration 3: Changes / Distsum = 726 / 750.5646
# Iteration 4: Changes / Distsum = 627 / 731.7791
# Iteration 5: Changes / Distsum = 717 / 717.6065
# Iteration 6: Changes / Distsum = 623 / 708.2896
# Iteration 7: Changes / Distsum = 458 / 700.1216
# Iteration 8: Changes / Distsum = 472 / 693.6942
# Iteration 9: Changes / Distsum = 301 / 690.6898
# Iteration 10: Changes / Distsum = 445 / 687.1226
# Iteration 11: Changes / Distsum = 475 / 683.108
# Iteration 12: Changes / Distsum = 244 / 681.6069
# Iteration 13: Changes / Distsum = 278 / 680.373
# Iteration 14: Changes / Distsum = 342 / 678.1872
# Iteration 15: Changes / Distsum = 279 / 676.351
# Iteration 16: Changes / Distsum = 158 / 675.5569
# Iteration 17: Changes / Distsum = 128 / 674.9877
# Iteration 18: Changes / Distsum = 371 / 673.3224
# Iteration 19: Changes / Distsum = 84 / 672.794
# Iteration 20: Changes / Distsum =  0 / 672.794
# Repetition 1 for k = 5
# Iteration 1: Changes / Distsum = 20749 / 2402.706
# Iteration 2: Changes / Distsum = 6015 / 802.8128
# Iteration 3: Changes / Distsum = 1650 / 697.1384
# Iteration 4: Changes / Distsum = 1345 / 672.4499
# Iteration 5: Changes / Distsum = 1233 / 651.4621
# Iteration 6: Changes / Distsum = 1183 / 635.2
# Iteration 7: Changes / Distsum = 1051 / 619.744
# Iteration 8: Changes / Distsum = 876 / 607.5059
# Iteration 9: Changes / Distsum = 883 / 596.1874
# Iteration 10: Changes / Distsum = 876 / 586.4765
# Iteration 11: Changes / Distsum = 405 / 581.7277
# Iteration 12: Changes / Distsum = 533 / 577.4692
# Iteration 13: Changes / Distsum = 560 / 573.7523
# Iteration 14: Changes / Distsum = 466 / 570.6262
# Iteration 15: Changes / Distsum = 294 / 569.5689
# Iteration 16: Changes / Distsum = 125 / 569.149
# Iteration 17: Changes / Distsum =  0 / 569.149
# Repetition 1 for k = 6
# Iteration 1: Changes / Distsum = 20749 / 1248.643
# Iteration 2: Changes / Distsum = 3775 / 822.8556
# Iteration 3: Changes / Distsum = 2872 / 667.516
# Iteration 4: Changes / Distsum = 1789 / 599.3408
# Iteration 5: Changes / Distsum = 1610 / 564.9663
# Iteration 6: Changes / Distsum = 982 / 547.0053
# Iteration 7: Changes / Distsum = 755 / 538.3919
# Iteration 8: Changes / Distsum = 664 / 531.7258
# Iteration 9: Changes / Distsum = 349 / 529.0205
# Iteration 10: Changes / Distsum = 331 / 527.4567
# Iteration 11: Changes / Distsum = 233 / 526.7358
# Iteration 12: Changes / Distsum = 146 / 526.1128
# Iteration 13: Changes / Distsum = 202 / 525.6032
# Iteration 14: Changes / Distsum = 0 / 525.6032
# Repetition 1 for k = 7
# Iteration 1: Changes / Distsum = 20749 / 716.0042
# Iteration 2: Changes / Distsum = 2369 / 493.0719
# Iteration 3: Changes / Distsum = 1172 / 465.1144
# Iteration 4: Changes / Distsum = 653 / 457.9252
# Iteration 5: Changes / Distsum = 590 / 454.133
# Iteration 6: Changes / Distsum = 350 / 452.6362
# Iteration 7: Changes / Distsum = 0 / 452.6362
#
# 	Elapsed time is 159.73 seconds.
#
#                 k_3          k_4          k_5          k_6          k_7
# Sil    5.938529e-01 5.523708e-01 4.901406e-01 4.893605e-01 4.574649e-01
# SF     6.083704e-01 5.889946e-01 5.880585e-01 5.769344e-01 5.727015e-01
# CH     5.939023e+04 3.344097e+04 3.732381e+04 3.726372e+04 2.973626e+04
# DB     4.132874e-01 6.173074e-01 3.394623e-01 1.572896e+00 3.680880e-01
# DBstar 5.523532e-01 9.586711e-01 6.608698e-01 2.795977e+00 7.748245e-01
# D      1.409436e-05 4.218211e-05 2.221472e-05 5.233068e-05 2.428838e-05
# COP    4.955784e-02 3.523231e-02 3.007377e-02 2.712020e-02 2.338508e-02
# Parsed with column specification:
# cols(
#   `0` = col_double(),
#   `1` = col_double(),
#   `2` = col_double(),
#   `3` = col_double(),
#   `4` = col_double(),
#   `5` = col_double(),
#   `6` = col_double()
# )
# 	Precomputing distance matrix...
# Repetition 1 for k = 3
# Iteration 1: Changes / Distsum = 20749 / 621680.7
# Iteration 2: Changes / Distsum = 1081 / 494728.7
# Iteration 3: Changes / Distsum = 419 / 487635.2
# Iteration 4: Changes / Distsum = 191 / 482946.5
# Iteration 5: Changes / Distsum = 0 / 482946.5
# Repetition 1 for k = 4
# Iteration 1: Changes / Distsum = 20749 / 808583.6
# Iteration 2: Changes / Distsum = 1462 / 431074.5
# Iteration 3: Changes / Distsum = 861 / 399960.2
# Iteration 4: Changes / Distsum = 232 / 388299.2
# Iteration 5: Changes / Distsum = 132 / 384829.8
# Iteration 6: Changes / Distsum = 154 / 381960.8
# Iteration 7: Changes / Distsum = 0 / 381960.8
# Repetition 1 for k = 5
# Iteration 1: Changes / Distsum = 20749 / 1686152
# Iteration 2: Changes / Distsum = 5924 / 452122.4
# Iteration 3: Changes / Distsum = 2216 / 368336.6
# Iteration 4: Changes / Distsum = 1121 / 345930.8
# Iteration 5: Changes / Distsum = 1172 / 333430.4
# Iteration 6: Changes / Distsum = 647 / 325081.6
# Iteration 7: Changes / Distsum = 260 / 323045.2
# Iteration 8: Changes / Distsum = 839 / 316864.5
# Iteration 9: Changes / Distsum = 665 / 312083.8
# Iteration 10: Changes / Distsum = 0 / 312083.8
# Repetition 1 for k = 6
# Iteration 1: Changes / Distsum = 20749 / 670563.3
# Iteration 2: Changes / Distsum = 3899 / 421464.4
# Iteration 3: Changes / Distsum = 2797 / 344669.2
# Iteration 4: Changes / Distsum = 2220 / 304208.3
# Iteration 5: Changes / Distsum = 1223 / 283490.8
# Iteration 6: Changes / Distsum = 343 / 278942.1
# Iteration 7: Changes / Distsum = 459 / 276336.3
# Iteration 8: Changes / Distsum = 0 / 276336.3
# Repetition 1 for k = 7
# Iteration 1: Changes / Distsum = 20749 / 396449.9
# Iteration 2: Changes / Distsum = 3140 / 245149.6
# Iteration 3: Changes / Distsum = 1793 / 224306.9
# Iteration 4: Changes / Distsum = 749 / 220643.7
# Iteration 5: Changes / Distsum = 223 / 219651
# Iteration 6: Changes / Distsum =   0 / 219651
#
# 	Elapsed time is 77.036 seconds.
#
#                  k_3           k_4           k_5           k_6           k_7
# Sil     6.250581e-01  5.733725e-01  4.728835e-01  4.747890e-01  4.581679e-01
# SF      0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# CH      4.092390e+04  3.570700e+04  3.051571e+04  2.795659e+04  3.262878e+04
# DB      2.993784e-01  3.496542e-01  4.214999e-01  7.402946e-01  4.698696e-01
# DBstar  4.041887e-01  5.185910e-01  1.060932e+00  1.624781e+00  1.226512e+00
# D      -1.786334e-05 -2.914086e-05 -9.925212e-06 -2.443231e-05 -2.382817e-05
# COP     1.981836e-02  1.147358e-02  1.335704e-02  9.579695e-03  6.896464e-03
# [1] "90_0.5.csv"
# Parsed with column specification:
# cols(
#   `0` = col_double(),
#   `1` = col_double(),
#   `2` = col_double(),
#   `3` = col_double(),
#   `4` = col_double(),
#   `5` = col_double(),
#   `6` = col_double()
# )
# Warning message in pam_distmat(series, control, distance, cent_char, family, args, :
# “Using dtw_lb with control$pam.precompute = TRUE is not advised.”
# 	Precomputing distance matrix...
# Repetition 1 for k = 3
# Iteration 1: Changes / Distsum = 34618 / 285611.3
# Iteration 2: Changes / Distsum = 2089 / 223681.2
# Iteration 3: Changes / Distsum = 911 / 219488
# Iteration 4: Changes / Distsum = 407 / 231785
# Iteration 5: Changes / Distsum =   0 / 231785
# Repetition 1 for k = 4
# Iteration 1: Changes / Distsum = 34618 / 477321.2
# Iteration 2: Changes / Distsum = 5578 / 265959.1
# Iteration 3: Changes / Distsum = 3490 / 253068.7
# Iteration 4: Changes / Distsum = 2163 / 245097.3
# Iteration 5: Changes / Distsum = 2977 / 209649.2
# Iteration 6: Changes / Distsum = 1515 / 213274
# Iteration 7: Changes / Distsum = 2733 / 205278.5
# Iteration 8: Changes / Distsum = 0 / 205278.5
# Repetition 1 for k = 5
# Iteration 1: Changes / Distsum = 34618 / 237464.9
# Iteration 2: Changes / Distsum = 1813 / 194669.4
# Iteration 3: Changes / Distsum = 455 / 193228
# Iteration 4: Changes / Distsum =   0 / 193228
# Repetition 1 for k = 6
# Iteration 1: Changes / Distsum = 34618 / 238792.1
# Iteration 2: Changes / Distsum = 4415 / 157858.5
# Iteration 3: Changes / Distsum = 1624 / 157740.8
# Iteration 4: Changes / Distsum = 2327 / 153536.8
# Iteration 5: Changes / Distsum = 1936 / 149757.7
# Iteration 6: Changes / Distsum = 430 / 154839
# Iteration 7: Changes / Distsum =   0 / 154839
# Repetition 1 for k = 7
# Iteration 1: Changes / Distsum = 34618 / 210976.1
# Iteration 2: Changes / Distsum = 5405 / 140020.9
# Iteration 3: Changes / Distsum = 2641 / 132726
# Iteration 4: Changes / Distsum = 2475 / 126229.5
# Iteration 5: Changes / Distsum = 2923 / 119812.4
# Iteration 6: Changes / Distsum = 2090 / 119354.4
# Iteration 7: Changes / Distsum = 257 / 119117.8
# Iteration 8: Changes / Distsum = 0 / 119117.8
#
# 	Elapsed time is 118.166 seconds.
# Warning message in FUN(X[[i]], ...):
# “Internal CVIs: series' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	Sil	D	COP”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: centroids' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	DB	DB*”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: series' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	Sil	D	COP”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: series' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	Sil	D	COP”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: centroids' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	DB	DB*”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: series' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	Sil	D	COP”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: centroids' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	DB	DB*”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: series' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	Sil	D	COP”
#                 k_3          k_4          k_5          k_6          k_7
# Sil    4.970794e-01 4.427635e-01 4.782526e-01 3.966405e-01 4.028982e-01
# SF     4.398869e-06 1.019742e-07 1.125975e-10 8.930454e-10 5.054046e-11
# CH     6.945945e+04 5.434814e+04 4.723023e+04 4.452848e+04 4.520923e+04
# DB     5.729963e-01 5.216869e-01 5.833855e-01 7.011201e-01 5.636742e-01
# DBstar 7.538315e-01 8.943564e-01 7.361697e-01 1.573721e+00 9.611474e-01
# D      0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00
# COP    1.159001e-01 1.057163e-01 5.865321e-02 6.287549e-02 3.669252e-02
# Parsed with column specification:
# cols(
#   `0` = col_double(),
#   `1` = col_double(),
#   `2` = col_double(),
#   `3` = col_double(),
#   `4` = col_double(),
#   `5` = col_double(),
#   `6` = col_double()
# )
# 	Precomputing distance matrix...
# Repetition 1 for k = 3
# Iteration 1: Changes / Distsum = 34618 / 101188.9
# Iteration 2: Changes / Distsum = 2668 / 352357.8
# Iteration 3: Changes / Distsum = 1177 / 346999.1
# Iteration 4: Changes / Distsum = 376 / 345331.7
# Iteration 5: Changes / Distsum = 418 / 342591.2
# Iteration 6: Changes / Distsum = 327 / 342514.8
# Iteration 7: Changes / Distsum = 220 / 347915.8
# Iteration 8: Changes / Distsum = 162 / 342395.6
# Iteration 9: Changes / Distsum = 0 / 342395.6
# Repetition 1 for k = 4
# Iteration 1: Changes / Distsum = 34618 / 385819.8
# Iteration 2: Changes / Distsum = 8346 / 389404.9
# Iteration 3: Changes / Distsum = 5185 / 341133.7
# Iteration 4: Changes / Distsum = 2762 / 312397.5
# Iteration 5: Changes / Distsum = 2436 / 308515.6
# Iteration 6: Changes / Distsum = 1638 / 302754
# Iteration 7: Changes / Distsum = 1561 / 302151.7
# Iteration 8: Changes / Distsum = 1124 / 296265.8
# Iteration 9: Changes / Distsum = 1175 / 294724.2
# Iteration 10: Changes / Distsum = 990 / 289754.8
# Iteration 11: Changes / Distsum = 654 / 287219.9
# Iteration 12: Changes / Distsum = 594 / 286823.6
# Iteration 13: Changes / Distsum = 599 / 287394.1
# Iteration 14: Changes / Distsum = 529 / 289905.8
# Iteration 15: Changes / Distsum = 26 / 289479.4
# Iteration 16: Changes / Distsum = 0 / 289479.4
# Repetition 1 for k = 5
# Iteration 1: Changes / Distsum = 34618 / 166666
# Iteration 2: Changes / Distsum = 3108 / 287197.6
# Iteration 3: Changes / Distsum = 1653 / 290923.5
# Iteration 4: Changes / Distsum = 1509 / 282468.4
# Iteration 5: Changes / Distsum = 1863 / 279691.5
# Iteration 6: Changes / Distsum = 1273 / 284359
# Iteration 7: Changes / Distsum = 1452 / 275517
# Iteration 8: Changes / Distsum = 1746 / 268799.9
# Iteration 9: Changes / Distsum = 1253 / 270066.6
# Iteration 10: Changes / Distsum = 934 / 271503.4
# Iteration 11: Changes / Distsum = 1192 / 268630.5
# Iteration 12: Changes / Distsum = 604 / 265238.6
# Iteration 13: Changes / Distsum = 645 / 263194.9
# Iteration 14: Changes / Distsum = 854 / 258581
# Iteration 15: Changes / Distsum = 1052 / 258217.1
# Iteration 16: Changes / Distsum = 1090 / 258003.1
# Iteration 17: Changes / Distsum = 340 / 258953.9
# Iteration 18: Changes / Distsum = 639 / 255393.4
# Iteration 19: Changes / Distsum = 1151 / 247805.5
# Iteration 20: Changes / Distsum = 1231 / 255704.2
# Iteration 21: Changes / Distsum = 589 / 258167.2
# Iteration 22: Changes / Distsum = 371 / 257889
# Iteration 23: Changes / Distsum = 361 / 260293.8
# Iteration 24: Changes / Distsum = 327 / 256514.9
# Iteration 25: Changes / Distsum = 595 / 253165
# Iteration 26: Changes / Distsum = 242 / 257470.3
# Iteration 27: Changes / Distsum = 0 / 257340.5
# Repetition 1 for k = 6
# Iteration 1: Changes / Distsum = 34618 / 61236.8
# Iteration 2: Changes / Distsum = 10966 / 305158.7
# Iteration 3: Changes / Distsum = 3309 / 269829.9
# Iteration 4: Changes / Distsum = 2440 / 260046.8
# Iteration 5: Changes / Distsum = 1802 / 251878
# Iteration 6: Changes / Distsum = 2181 / 251042.4
# Iteration 7: Changes / Distsum = 1723 / 246982.3
# Iteration 8: Changes / Distsum = 1288 / 249849.3
# Iteration 9: Changes / Distsum = 1079 / 250826
# Iteration 10: Changes / Distsum = 1039 / 249246.5
# Iteration 11: Changes / Distsum = 1204 / 246559
# Iteration 12: Changes / Distsum = 315 / 246295.5
# Iteration 13: Changes / Distsum = 797 / 245439.9
# Iteration 14: Changes / Distsum = 713 / 234707
# Iteration 15: Changes / Distsum = 650 / 237597.6
# Iteration 16: Changes / Distsum = 814 / 241768.1
# Iteration 17: Changes / Distsum = 1174 / 242155.7
# Iteration 18: Changes / Distsum = 821 / 242389.6
# Iteration 19: Changes / Distsum = 650 / 241165.1
# Iteration 20: Changes / Distsum = 513 / 241066.2
# Iteration 21: Changes / Distsum = 335 / 241336.4
# Iteration 22: Changes / Distsum = 440 / 242275.3
# Iteration 23: Changes / Distsum = 86 / 241545.1
# Iteration 24: Changes / Distsum = 0 / 241545.1
# Repetition 1 for k = 7
# Iteration 1: Changes / Distsum = 34618 / 51240.6
# Iteration 2: Changes / Distsum = 11408 / 278275
# Iteration 3: Changes / Distsum = 7474 / 246689.9
# Iteration 4: Changes / Distsum = 3711 / 232049.6
# Iteration 5: Changes / Distsum = 2001 / 224094.9
# Iteration 6: Changes / Distsum = 1648 / 226183.4
# Iteration 7: Changes / Distsum = 1024 / 226529.6
# Iteration 8: Changes / Distsum = 764 / 227991.2
# Iteration 9: Changes / Distsum = 350 / 227656.1
# Iteration 10: Changes / Distsum = 832 / 226953.6
# Iteration 11: Changes / Distsum = 1078 / 223827.1
# Iteration 12: Changes / Distsum = 299 / 223061.9
# Iteration 13: Changes / Distsum = 410 / 223666.4
# Iteration 14: Changes / Distsum = 518 / 223575.7
# Iteration 15: Changes / Distsum = 1173 / 222171.2
# Iteration 16: Changes / Distsum = 303 / 224441.2
# Iteration 17: Changes / Distsum = 253 / 224461.1
# Iteration 18: Changes / Distsum = 348 / 222249.5
# Iteration 19: Changes / Distsum = 942 / 224679
# Iteration 20: Changes / Distsum = 288 / 226890.6
# Iteration 21: Changes / Distsum = 0 / 226890.6
#
# 	Elapsed time is 238.858 seconds.
# Warning message in FUN(X[[i]], ...):
# “Internal CVIs: series' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	Sil	D	COP”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: centroids' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	DB	DB*”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: series' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	Sil	D	COP”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: centroids' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	DB	DB*”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: series' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	Sil	D	COP”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: centroids' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	DB	DB*”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: series' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	Sil	D	COP”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: centroids' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	DB	DB*”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: series' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	Sil	D	COP”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: centroids' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	DB	DB*”
#                 k_3          k_4          k_5          k_6          k_7
# Sil    5.557416e-01 4.992389e-01 4.867321e-01 4.390571e-01 4.212314e-01
# SF     9.079848e-12 1.143530e-13 2.220446e-16 0.000000e+00 0.000000e+00
# CH     3.065702e+04 2.659022e+04 2.315715e+04 1.962684e+04 1.750767e+04
# DB     6.932689e-01 7.584339e-01 7.888840e-01 8.695328e-01 9.605719e-01
# DBstar 8.427869e-01 1.014194e+00 1.040538e+00 1.292908e+00 1.346174e+00
# D      0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00
# COP    4.485362e-01 3.477876e-01 1.958498e-01 2.118977e-01 1.507674e-01
# Parsed with column specification:
# cols(
#   `0` = col_double(),
#   `1` = col_double(),
#   `2` = col_double(),
#   `3` = col_double(),
#   `4` = col_double(),
#   `5` = col_double(),
#   `6` = col_double()
# )
# 	Precomputing distance matrix...
# Repetition 1 for k = 3
# Iteration 1: Changes / Distsum = 34618 / 285611.3
# Iteration 2: Changes / Distsum = 2089 / 223681.2
# Iteration 3: Changes / Distsum = 911 / 219488
# Iteration 4: Changes / Distsum = 407 / 231785
# Iteration 5: Changes / Distsum =   0 / 231785
# Repetition 1 for k = 4
# Iteration 1: Changes / Distsum = 34618 / 477321.2
# Iteration 2: Changes / Distsum = 5578 / 265959.1
# Iteration 3: Changes / Distsum = 3490 / 253068.7
# Iteration 4: Changes / Distsum = 2163 / 245097.3
# Iteration 5: Changes / Distsum = 2977 / 209649.2
# Iteration 6: Changes / Distsum = 1515 / 213274
# Iteration 7: Changes / Distsum = 2733 / 205278.5
# Iteration 8: Changes / Distsum = 0 / 205278.5
# Repetition 1 for k = 5
# Iteration 1: Changes / Distsum = 34618 / 237464.9
# Iteration 2: Changes / Distsum = 1813 / 194669.4
# Iteration 3: Changes / Distsum = 455 / 193228
# Iteration 4: Changes / Distsum =   0 / 193228
# Repetition 1 for k = 6
# Iteration 1: Changes / Distsum = 34618 / 238792.1
# Iteration 2: Changes / Distsum = 4415 / 157858.5
# Iteration 3: Changes / Distsum = 1624 / 157740.8
# Iteration 4: Changes / Distsum = 2327 / 153536.8
# Iteration 5: Changes / Distsum = 1936 / 149757.7
# Iteration 6: Changes / Distsum = 430 / 154839
# Iteration 7: Changes / Distsum =   0 / 154839
# Repetition 1 for k = 7
# Iteration 1: Changes / Distsum = 34618 / 210976.1
# Iteration 2: Changes / Distsum = 5405 / 140020.9
# Iteration 3: Changes / Distsum = 2641 / 132726
# Iteration 4: Changes / Distsum = 2475 / 126229.5
# Iteration 5: Changes / Distsum = 2923 / 119812.4
# Iteration 6: Changes / Distsum = 2090 / 119354.4
# Iteration 7: Changes / Distsum = 257 / 119117.8
# Iteration 8: Changes / Distsum = 0 / 119117.8
#
# 	Elapsed time is 116.685 seconds.
# Warning message in FUN(X[[i]], ...):
# “Internal CVIs: series' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	Sil	D	COP”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: centroids' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	DB	DB*”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: series' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	Sil	D	COP”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: series' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	Sil	D	COP”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: centroids' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	DB	DB*”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: series' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	Sil	D	COP”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: centroids' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	DB	DB*”Warning message in FUN(X[[i]], ...):
# “Internal CVIs: series' cross-distance matrix is NOT symmetric, which can be problematic for:
# 	Sil	D	COP”
#                 k_3          k_4          k_5          k_6          k_7
# Sil    4.970794e-01 4.427635e-01 4.782526e-01 3.966405e-01 4.028982e-01
# SF     2.969952e-08 2.369249e-09 4.768630e-12 8.765855e-11 9.052536e-12
# CH     3.070102e+04 2.506722e+04 2.272214e+04 2.297388e+04 2.502813e+04
# DB     5.729963e-01 5.216869e-01 5.833855e-01 7.011201e-01 5.636742e-01
# DBstar 7.538315e-01 8.943564e-01 7.361697e-01 1.573721e+00 9.611474e-01
# D      0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00
# COP    1.159001e-01 1.057163e-01 5.865321e-02 6.287549e-02 3.669252e-02
# Parsed with column specification:
# cols(
#   `0` = col_double(),
#   `1` = col_double(),
#   `2` = col_double(),
#   `3` = col_double(),
#   `4` = col_double(),
#   `5` = col_double(),
#   `6` = col_double()
# )
# 	Precomputing distance matrix...
# Repetition 1 for k = 3
# Iteration 1: Changes / Distsum = 34618 / 189.5795
# Iteration 2: Changes / Distsum = 2765 / 130.1815
# Iteration 3: Changes / Distsum = 787 / 127.098
# Iteration 4: Changes / Distsum = 385 / 126.7863
# Iteration 5: Changes / Distsum = 203 / 126.6981
# Iteration 6: Changes / Distsum = 271 / 126.6471
# Iteration 7: Changes / Distsum = 0 / 126.6471
# Repetition 1 for k = 4
# Iteration 1: Changes / Distsum = 34618 / 191.8108
# Iteration 2: Changes / Distsum = 5459 / 124.0433
# Iteration 3: Changes / Distsum = 2737 / 109.8823
# Iteration 4: Changes / Distsum = 1721 / 105.6275
# Iteration 5: Changes / Distsum = 906 / 104.9899
# Iteration 6: Changes / Distsum = 737 / 104.2828
# Iteration 7: Changes / Distsum = 244 / 104.2314
# Iteration 8: Changes / Distsum = 0 / 104.2314
# Repetition 1 for k = 5
# Iteration 1: Changes / Distsum = 34618 / 204.8311
# Iteration 2: Changes / Distsum = 8881 / 124.1
# Iteration 3: Changes / Distsum = 5309 / 109.3094
# Iteration 4: Changes / Distsum = 3616 / 100.4124
# Iteration 5: Changes / Distsum = 2205 / 96.54544
# Iteration 6: Changes / Distsum = 1972 / 94.96329
# Iteration 7: Changes / Distsum = 1079 / 94.59378
# Iteration 8: Changes / Distsum = 1271 / 93.94949
# Iteration 9: Changes / Distsum = 599 / 93.66277
# Iteration 10: Changes / Distsum = 436 / 93.44581
# Iteration 11: Changes / Distsum = 670 / 93.24488
# Iteration 12: Changes / Distsum = 522 / 93.12692
# Iteration 13: Changes / Distsum = 703 / 92.93817
# Iteration 14: Changes / Distsum = 564 / 92.79377
# Iteration 15: Changes / Distsum = 377 / 92.46049
# Iteration 16: Changes / Distsum = 610 / 92.32741
# Iteration 17: Changes / Distsum = 318 / 92.30506
# Iteration 18: Changes / Distsum = 0 / 92.30506
# Repetition 1 for k = 6
# Iteration 1: Changes / Distsum = 34618 / 119.7735
# Iteration 2: Changes / Distsum = 3860 / 91.12773
# Iteration 3: Changes / Distsum = 1755 / 88.51156
# Iteration 4: Changes / Distsum = 1952 / 87.10931
# Iteration 5: Changes / Distsum = 1235 / 86.61152
# Iteration 6: Changes / Distsum = 634 / 86.4568
# Iteration 7: Changes / Distsum = 572 / 86.37407
# Iteration 8: Changes / Distsum = 1048 / 86.04187
# Iteration 9: Changes / Distsum = 460 / 85.9329
# Iteration 10: Changes / Distsum = 593 / 85.84302
# Iteration 11: Changes / Distsum = 431 / 85.78955
# Iteration 12: Changes / Distsum = 581 / 85.69385
# Iteration 13: Changes / Distsum = 145 / 85.64333
# Iteration 14: Changes / Distsum = 0 / 85.64333
# Repetition 1 for k = 7

# %% [markdown]
# ### CVI plot

# %%
cvis<-list()
file_head='/Users/wang/work/bgprophet/libre/cvi'
for (file in list.files(file_head)){
  print(file)
  cvi <- read_csv(file.path(file_head,file))
  
  cvi[3,2:6] <- cvi[3,2:6]/10000 # normalize CH values
  
  df<-melt(cvi)
  names(df) <- c('metrics', 'cluster_num', 'value')
  print(df)
  pl=
    ggplot(df, aes(cluster_num, value, group=factor(metrics)))+
    geom_line(aes(color=factor(metrics)))+
    labs(title=gsub('.csv','',file))
  
  cvis[[file]]<-pl
}
ggarrange(plotlist = cvis)
grobs<-arrangeGrob(cvis, nrow = 2)
ggsave('cvis.pdf', grobs)

# %% [markdown]
# ## Kmeans

# %%
k6 <- kmeans(df_raw, centers = 6, nstart = 25)

# %%
df=df_raw
k3 <- kmeans(df, centers = 3, nstart = 25)
k4 <- kmeans(df, centers = 4, nstart = 25)
k5 <- kmeans(df, centers = 5, nstart = 25)

# plots to compare
p1 <- fviz_cluster(k2, geom = "point", data = df) + ggtitle("k = 2")
p2 <- fviz_cluster(k3, geom = "point",  data = df) + ggtitle("k = 3")
p3 <- fviz_cluster(k4, geom = "point",  data = df) + ggtitle("k = 4")
p4 <- fviz_cluster(k5, geom = "point",  data = df) + ggtitle("k = 5")

library(gridExtra)
grid.arrange(p1, p2, p3, p4, nrow = 2)
# Out:
# Attaching package: ‘gridExtra’
#
# The following object is masked from ‘package:dplyr’:
#
#     combine
# plot without title

# %% [markdown]
# ## Evaluation methods

# %% [markdown]
# ### Elbow method

# %%
set.seed(123)

# function to compute total within-cluster sum of square 
wss <- function(k) {
  kmeans(df, k, nstart = 10 )$tot.withinss
}

# Compute and plot wss for k = 1 to k = 15
k.values <- 1:15

# extract wss for 2-15 clusters
wss_values <- map_dbl(k.values, wss)

plot(k.values, wss_values,
       type="b", pch = 19, frame = FALSE, 
       xlab="Number of clusters K",
       ylab="Total within-clusters sum of squares")

# %% [markdown]
# ### Average Silhouette Method

# %%
# function to compute average silhouette for k clusters
avg_sil <- function(k) {
  km.res <- kmeans(df, centers = k, nstart = 25)
  ss <- silhouette(km.res$cluster, dist(df))
  mean(ss[, 3])
}

# Compute and plot wss for k = 2 to k = 15
k.values <- 2:15

# extract avg silhouette for 2-15 clusters
avg_sil_values <- map_dbl(k.values, avg_sil)

plot(k.values, avg_sil_values,
       type = "b", pch = 19, frame = FALSE, 
       xlab = "Number of clusters K",
       ylab = "Average Silhouettes")
# Out:
# Error: cannot allocate vector of size 158.3 Gb
# Traceback:
#
# 1. map_dbl(k.values, avg_sil)
# 2. .f(.x[[i]], ...)
# 3. silhouette(km.res$cluster, dist(df))   # at line 4 of file <text>
# 4. silhouette.default(km.res$cluster, dist(df))

# %% [markdown]
# ## Using compare_clustering

# %%
# Fuzzy preprocessing: calculate autocorrelation up to 50th lag
acf_fun <- function(series, ...) {
    lapply(series, function(x) {
        as.numeric(acf(x, lag.max = 50, plot = FALSE)$acf)
    })
}

# Define overall configuration
cfgs <- compare_clusterings_configs(
    types = c("p", "h", "f", "t"),
    k = 19L:20L,
    controls = list(
        partitional = partitional_control(
            iter.max = 30L,
            nrep = 1L
        ),
        hierarchical = hierarchical_control(
            method = "all"
        ),
        fuzzy = fuzzy_control(
            # notice the vector
            fuzziness = c(2, 2.5),
            iter.max = 30L
        ),
        tadpole = tadpole_control(
            # notice the vectors
            dc = c(1.5, 2),
            window.size = 19L:20L
        )
    ),
    preprocs = pdc_configs(
        type = "preproc",
        # shared
        none = list(),
        zscore = list(center = c(FALSE)),
        # only for fuzzy
        fuzzy = list(
            acf_fun = list()
        ),
        # only for tadpole
        tadpole = list(
            reinterpolate = list(new.length = 205L)
        ),
        # specify which should consider the shared ones
        share.config = c("p", "h")
    ),
    distances = pdc_configs(
        type = "distance",
        sbd = list(),
        fuzzy = list(
            L2 = list()
        ),
        share.config = c("p", "h")
    ),
    centroids = pdc_configs(
        type = "centroid",
        partitional = list(
            pam = list()
        ),
        # special name 'default'
        hierarchical = list(
            default = list()
        ),
        fuzzy = list(
            fcmdd = list()
        ),
        tadpole = list(
            default = list(),
            shape_extraction = list(znorm = TRUE)
        )
    )
)

# Number of configurations is returned as attribute
num_configs <- sapply(cfgs, attr, which = "num.configs")
cat("\nTotal number of configurations without considering optimizations:",
    sum(num_configs),
    "\n\n")


# Define evaluation functions based on CVI: Variation of Information (only crisp partition)
# vi_evaluators <- cvi_evaluators("VI")
# score_fun <- vi_evaluators$score
# pick_fun <- vi_evaluators$pick
# Out:
# Total number of configurations without considering optimizations: 56

# %% [markdown]
# ### Visualization

# %%
library(tibbletime)
library(dplyr)
# Out:
# Attaching package: ‘tibbletime’
#
# The following object is masked from ‘package:stats’:
#
#     filter

# %%
case1 <- read.csv('../data/libre_clean/1Chloe AliceEtherington_glucose_5-8-2019.csv')

# %%
head(case1)
# Out:
#   time                bg   No
# 1 2019-01-30 15:26:00   NA 1
# 2 2019-01-30 16:26:00 13.5 1
# 3 2019-01-30 16:26:00   NA 1
# 4 2019-01-30 16:26:00   NA 1
# 5 2019-01-30 16:28:00 13.9 1
# 6 2019-01-30 16:36:00 14.4 1

# %%
case1$time <- as.POSIXct(case1$time)

# %%
for (file in list.files('../data/libre_clean/')){
    case <- read.csv(file.path('../data/libre_clean/',file))
    case$time <- as.POSIXct(case$time)
    ggplot(data=case) + geom_line(mapping = aes(x=time, y=bg)) + labs(title = file)  
}

# %%
file = '3JohnValentine_glucose_5-8-2019.csv'
case <- read.csv(file.path('../data/libre_clean/',file))
case$time <- as.POSIXct(case$time)

# %%
# df_all <- read_csv(file.path('./datasets4/2_90_0.csv')) 

df_all <- read_csv(file.path('./datasets4/dfs_p_90_0.csv'))
# Out:
# Parsed with column specification:
# cols(
#   `0` = col_double(),
#   `1` = col_datetime(format = ""),
#   `2` = col_double(),
#   `3` = col_double(),
#   `4` = col_double(),
#   `5` = col_double(),
#   `6` = col_double(),
#   `7` = col_double(),
#   `8` = col_double()
# )

# %%
df <- df_all %>% select(3:9)

# %%
head(df)
# Out:
#   2    3    4    5    6    7    8
# 1 15.7 15.6 16.0 16.1 15.3 15.6 15.8
# 2 15.1 14.7 13.8 13.6 14.1 14.7 14.9
# 3 14.9 14.9 15.5 16.2 16.3 15.9 15.7
# 4 13.1 14.1 15.1 14.5 14.6 15.8 16.4
# 5 16.4 16.6 16.3 16.1 16.3 16.4 16.3
# 6 16.3 16.3 16.5 16.1 15.8 15.9 15.8

# %%
# df <- read_csv(file.path('./datasets3/90_0.csv'))
pc <- tsclust(df, type = "partitional", k = 3L:7L, 
           distance = "sdtw", centroid = "pam", 
           seed = 3247L, trace = TRUE)
names(pc) <-paste0("k_", 3L:7L)
# Out:
# 	Precomputing distance matrix...
# Repetition 1 for k = 3
# Iteration 1: Changes / Distsum = 17256 / 618035.5
# Iteration 2: Changes / Distsum = 601 / 415347.1
# Iteration 3: Changes / Distsum = 115 / 414709.4
# Iteration 4: Changes / Distsum = 0 / 414709.4
# Repetition 1 for k = 4
# Iteration 1: Changes / Distsum = 17256 / 620774.4
# Iteration 2: Changes / Distsum = 1319 / 369293.3
# Iteration 3: Changes / Distsum = 1145 / 361286.7
# Iteration 4: Changes / Distsum = 1560 / 336142
# Iteration 5: Changes / Distsum = 1113 / 321174.9
# Iteration 6: Changes / Distsum = 300 / 317952.7
# Iteration 7: Changes / Distsum = 420 / 314351.6
# Iteration 8: Changes / Distsum = 479 / 311150.7
# Iteration 9: Changes / Distsum = 530 / 306870.4
# Iteration 10: Changes / Distsum = 148 / 304809.5
# Iteration 11: Changes / Distsum = 0 / 304809.5
# Repetition 1 for k = 5
# Iteration 1: Changes / Distsum = 17256 / 1293127
# Iteration 2: Changes / Distsum = 3346 / 427776.5
# Iteration 3: Changes / Distsum = 1326 / 356204
# Iteration 4: Changes / Distsum = 1347 / 325564.6
# Iteration 5: Changes / Distsum = 1645 / 303845.9
# Iteration 6: Changes / Distsum = 770 / 298146.5
# Iteration 7: Changes / Distsum = 1545 / 287265
# Iteration 8: Changes / Distsum = 915 / 274243.2
# Iteration 9: Changes / Distsum = 501 / 272226.9
# Iteration 10: Changes / Distsum = 0 / 272226.9
# Repetition 1 for k = 6
# Iteration 1: Changes / Distsum = 17256 / 349774.4
# Iteration 2: Changes / Distsum = 1360 / 230279.1
# Iteration 3: Changes / Distsum = 1302 / 220568.5
# Iteration 4: Changes / Distsum = 987 / 214596.2
# Iteration 5: Changes / Distsum = 0 / 214596.2
# Repetition 1 for k = 7
# Iteration 1: Changes / Distsum = 17256 / 594593.9
# Iteration 2: Changes / Distsum = 3004 / 268960.9
# Iteration 3: Changes / Distsum = 1688 / 226465.1
# Iteration 4: Changes / Distsum = 1078 / 200894.5
# Iteration 5: Changes / Distsum = 466 / 198339.8
# Iteration 6: Changes / Distsum = 726 / 193218.2
# Iteration 7: Changes / Distsum = 249 / 191344.2
# Iteration 8: Changes / Distsum = 462 / 185795.7
# Iteration 9: Changes / Distsum = 169 / 184803.8
# Iteration 10: Changes / Distsum = 106 / 184462.7
# Iteration 11: Changes / Distsum = 0 / 184462.7
#
# 	Elapsed time is 58.756 seconds.

# %%
display.brewer.all()
# Out:
# plot without title

# %%
df_clust <- df_all %>% mutate(k_3=pc$k_3@cluster, k_4=pc$k_4@cluster, k_5=pc$k_5@cluster, k_6=pc$k_6@cluster, k_7=pc$k_7@cluster)

# %%
names(df_clust) <- c('No', 'time', '1','2','3','4','5','6','7','k_3', 'k_4', 'k_5', 'k_6', 'k_7')

# %%
centroids <-tibble(pc$k_6@centroids)

# %%
z1<-data.frame(x=1L:7L, y=pc$k_6@centroids[1])
names(z1) <- c('x', 'y')
cc1 <- ggplot(z1, aes(x, y)) +geom_line() + ggtitle('k_1')

z2<-data.frame(x=1L:7L, y=pc$k_6@centroids[2])
names(z2) <- c('x', 'y')
cc2 <- ggplot(z2, aes(x, y)) +geom_line() + ggtitle('k_2')

z3<-data.frame(x=1L:7L, y=pc$k_6@centroids[3])
names(z3) <- c('x', 'y')
cc3 <- ggplot(z3, aes(x, y)) +geom_line() + ggtitle('k_3')

z4<-data.frame(x=1L:7L, y=pc$k_6@centroids[4])
names(z4) <- c('x', 'y')
cc4 <- ggplot(z4, aes(x, y)) +geom_line() + ggtitle('k_4')

z5<-data.frame(x=1L:7L, y=pc$k_6@centroids[5])
names(z5) <- c('x', 'y')
cc5 <- ggplot(z5, aes(x, y)) +geom_line() + ggtitle('k_5')

z6<-data.frame(x=1L:7L, y=pc$k_6@centroids[6])
names(z6) <- c('x', 'y')
cc6 <- ggplot(z6, aes(x, y)) +geom_line() + ggtitle('k_6')

# ccs <- list()
# for (i in 1L:6L){
#     z<-data.frame(x=1L:7L, y=pc$k_6@centroids[i])
#     names(z) <- c('x', 'y')
#     cc <- ggplot(z, aes(x, y)) +geom_line() + ggtitle(i)
#     ccs[i]<-cc
# }

# %%
library(gridExtra)
# plots = mget(cc1,cc2,cc3,cc4,cc5,cc6)
grid.arrange(cc1,cc2,cc3,cc4,cc5,cc6, nrow = 2)
grobs<-arrangeGrob(cc1,cc2,cc3,cc4,cc5,cc6, nrow = 2)
ggsave('centroids.pdf', grobs)
# Out:
# Saving 6.67 x 6.67 in image
# plot without title

# %%
plot(pc$k_6)
ggsave('all_clusters_variations.pdf')
# Out:
# Saving 6.67 x 6.67 in image
# plot without title

# %%
tally_clust <- df_clust %>% group_by(No, k_6) %>% tally() %>% spread(k_6, n)

# %%
tally_clust[2:7]
# Out:
#    1   2   3   4   5   6
# 1  151 130 430  99  30 471
# 2  194 100 241 178 212 209
# 3  862 312 861 590 641 792
# 4   91  87 138  81  32 151
# 5  100  24 104  79 117  96
# 6   66  25  72  65  88  54
# 7   76  84 172  63  15 223
# 8  131   1  26  82 169   8
# 9  318 117 338 234 208 234
# 10  97  19  67 107 128  55
# 11 100  20  57  76 248  53
# 12  22  22  28  30  43  38
# 13 119   9  97  99 146  58
# 14  69  24  55  43 106  68
# 15 136  NA  74  87 303  15
# 16 211  NA  85 137 145  28
# 17 302 176 293 297 261 290
# 18  46  14  29  58  79  32
# 19  72  NA   8  39 513  NA
# 20 285  20 218 222 109  97

# %%
pdf(file="heatmap-20instances.pdf")
heatmap(as.matrix(tally_clust[2:7]), Colv = NA , xlab = 'specification variations', ylab='Instance numbers')
dev.off()
# Out:
# png
#   2

# %%
tally_clust %>% spread(k_5, n)
# Out:
#    No 1    2   3   4   5
# 1   1  603  11 260 334 103
# 2   2  297 152 265 195 225
# 3   3 1130 394 963 679 892
# 4   4  186  18 129 170  77
# 5   5  142  84 130  63 101
# 6   6  103  70  77  43  77
# 7   7  255   7 121 192  58
# 8   8   29  68  72   2 246
# 9   9  430 117 375 214 313
# 10 10  110  87 109  35 132
# 11 11   88 211  94  39 122
# 12 12   45  33  41  35  29
# 13 13  121 102 142  24 139
# 14 14   86  83  68  56  72
# 15 15   76 244 120   4 171
# 16 16   75  82 204   9 236
# 17 17  387 172 393 330 337
# 18 18   50  66  67  22  53
# 19 19    3 473  43  NA 113
# 20 20  244  50 329  50 278

# %%
time_all <- read_csv(file.path('./datasets4/times_all_case3.csv'))

# %%
df_clust_3_gathered <-
df_clust %>% 
filter(No==3) %>%
gather('1','2','3','4','5','6','7', key='sub_index', value='bg') %>%
mutate(time_all=times_all$'0')
# pc$k_3@cluster

# %%
head(df_clust_3_gathered)
# Out:
#   No time                k_3 k_4 k_5 k_6 k_7 sub_index bg   time_all
# 1 3  2018-02-14 18:48:00 1   2   5   1   7   1          6.8 2018-02-14 18:48:00
# 2 3  2018-02-14 19:20:00 2   2   5   4   2   1          7.7 2018-02-14 19:03:00
# 3 3  2018-02-14 20:05:00 2   4   5   5   6   1          5.7 2018-02-14 19:18:00
# 4 3  2018-02-14 20:48:00 1   2   3   4   5   1         10.6 2018-02-14 19:33:00
# 5 3  2018-02-15 01:07:00 2   2   5   1   7   1          4.8 2018-02-14 19:48:00
# 6 3  2018-02-15 06:39:00 3   3   4   6   3   1         16.0 2018-02-14 20:03:00

# %% [markdown]
# ### One-day cluster visualization

# %%
df_clust_3_gathered_one_day = filter(df_clust_3_gathered, time_all > '2019-01-01' & time_all<'2019-01-02')

# %%
df_clust_3_gathered_one_week = filter(df_clust_3_gathered, time_all > '2019-01-01' & time_all<'2019-01-08')

# %%
cluster_visual <- function(dataset, title){

    myPalette <- colorRampPalette(rev(brewer.pal(8, "Accent")))
    sc <- scale_colour_gradientn(colours = myPalette(100), limits=c(1, 8))

    ggplot()+
    geom_line(data=dataset,mapping = aes(x=time_all, y=bg, color = k_6), size=2)+
    sc+
    labs(title = title)  

    ggsave(title, width = 20, height = 10,limitsize = FALSE)
}

# %%
cluster_visual(df_clust_3_gathered_one_day, 'case3_one_day.pdf')

# %%
cluster_visual(df_clust_3_gathered_one_week, 'case3_one_week.pdf')
