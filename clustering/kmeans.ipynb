# %%
import os
import gzip
import json
import pandas as pd
import _pickle as pickle
import numpy as np
import matplotlib.pyplot as plt
import datetime
from fbprophet import Prophet
# %matplotlib inline

# %%
bg_path = '/home/jupyter/work/openaps/data/99908129/direct-sharing-31/entries_2017-01-01_to_2017-10-24.json'
df_bg = pd.read_json(bg_path)

# %%
bg_path_2 = '/home/jupyter/work/openaps/data/28176124/direct-sharing-31/entries__to_2018-11-05.json'
df_bg_2 = pd.read_json(bg_path_2)

# %%
df_bg_2.head()
# Out:
#                         _id  _tell body                date  \
# 0  5bdf8ae613b69104b6dc8580      5  NaN 2018-11-04 23:58:00
# 1  5bdf885413b69104b6dc73d3      2  NaN 2018-11-04 23:58:00
# 2  5bdf885413b69104b6dc73d5      3  NaN 2018-11-04 23:53:00
# 3  5bdf876213b69104b6dc6d3a      2  NaN 2018-11-04 23:53:00
# 4  5bdf876213b69104b6dc6d3b     18  NaN 2018-11-04 23:48:00
#
#                   dateString date_type                        device  \
# 0  2018-11-05T01:58:00+02:00  relative  openaps://medtronic/pump/cgm
# 1  2018-11-05T01:58:00+02:00  relative  openaps://medtronic/pump/cgm
# 2  2018-11-05T01:53:00+02:00  relative  openaps://medtronic/pump/cgm
# 3  2018-11-05T01:53:00+02:00  relative  openaps://medtronic/pump/cgm
# 4  2018-11-05T01:48:00+02:00  relative  openaps://medtronic/pump/cgm
#
#        direction               display_time  glucose               name  op  \
# 0  FortyFiveDown  2018-11-05T01:58:00+02:00      140  GlucoseSensorData  70
# 1     SingleDown  2018-11-05T01:58:00+02:00      140  GlucoseSensorData  70
# 2            NaN  2018-11-05T01:53:00+02:00      150  GlucoseSensorData  75
# 3     SingleDown  2018-11-05T01:53:00+02:00      150  GlucoseSensorData  75
# 4  FortyFiveDown  2018-11-05T01:48:00+02:00      164  GlucoseSensorData  82
#
#    packet_size  raw  sgv  trend_arrow type
# 0            0  NaN  140      45_DOWN  sgv
# 1            0  NaN  140  SINGLE_DOWN  sgv
# 2            0  NaN  150          NaN  sgv
# 3            0  NaN  150  SINGLE_DOWN  sgv
# 4            0  NaN  164      45_DOWN  sgv

# %%
def prophet_pre(df):
    df['ds']=df['date']
    df['y'] = df['sgv']
    return df[['ds', 'y']]

# %%
df_bg_2['ds'] = df_bg_2['date']
df_bg_2['y'] = df_bg_2['sgv']

# %%
m_2 = Prophet()
m_2.fit(df_bg_2)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-f99cfce198c3> in <module>
#       1 m_2 = Prophet()
#       2 m_2.fit(df_bg_2)
# ----> 3 fig1 = m2.plot(forecast)
#
# NameError: name 'm2' is not defined

# %%
future = m_2.make_future_dataframe(periods=10)
forecast_2 = m.predict(future)
fig1 = m_2.plot(forecast_2)

# %%
m_2.plot_components(forecast)

# %%
cols=['date', 'sgv','type']
df_bg=df_bg[cols]
# df_bg = df_bg.set_index('date').sort_index()

# %%
start='2017-05-01'
end='2017-06-01'
test_range = pd.date_range(start, end)

# %%
m = Prophet()
df_bg['ds']=df_bg['date']
df_bg['y'] = df_bg['sgv']
df_bg = df_bg.set_index('date').sort_index()
m.fit(df_bg[start:end])
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %%
future = m.make_future_dataframe(periods=10)
future.tail()
# Out:
#                       ds
# 9051 2017-06-07 23:56:05
# 9052 2017-06-08 23:56:05
# 9053 2017-06-09 23:56:05
# 9054 2017-06-10 23:56:05
# 9055 2017-06-11 23:56:05

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#                       ds        yhat  yhat_lower  yhat_upper
# 9051 2017-06-07 23:56:05  126.422654   73.875480  183.545416
# 9052 2017-06-08 23:56:05  116.601226   56.129063  174.443818
# 9053 2017-06-09 23:56:05  111.398085   57.292484  171.577801
# 9054 2017-06-10 23:56:05  135.371468   82.468462  191.900459
# 9055 2017-06-11 23:56:05  136.410619   80.375640  197.832060

# %%
fig1 = m.plot(forecast)

# %%
fig2 = m.plot_components(forecast)

# %%
df_bg[start:end].plot(y='sgv', figsize=(20, 6))

# %% [raw]
# for d in test_range:
#     oneday_variation =  df_bg[str(d):str(d+pd.Timedelta(days=1))]
#     if oneday_variation.empty:
#         continue
#     oneday_variation.plot(y='sgv')
