# %%
import pandas as pd
import pickle
import matplotlib as plt

# %%
df_s_lstm = pickle.load(open('/home/jupyter/work/bgprophet/results/predict_s_lstm_2018-12-01.pkl'))

# %%
df_s_lstm.head()
# Out:
#         y_pred  y_true
# 0  [103.41778]     102
# 1  [100.72022]      98
# 2   [95.29764]      93
# 3   [89.68164]      88
# 4   [84.75274]      85

# %%
df_s_lstm.y_pred = df_s_lstm.y_pred.apply(lambda x:x[0])

# %%
df_s_lstm.describe()
# Out:
#              y_pred        y_true
# count  27164.000000  27164.000000
# mean     134.994065    135.176668
# std       42.734990     43.093720
# min       -3.670416      1.000000
# 25%      102.180019    102.000000
# 50%      127.568844    128.000000
# 75%      162.794369    163.000000
# max      325.017670    323.000000

# %%
df_s_lstm[:100].plot.line(figsize=(20,5))

# %%
df_v_lstm = pickle.load(open('/home/jupyter/work/bgprophet/results/predict_v_lstm_2018-12-01.pkl'))

# %%
df_v_lstm.y_pred = df_v_lstm.y_pred.apply(lambda x:x[0])

# %%
df_v_lstm[:100].plot.line(figsize=(10,5))

# %%
df_v_lstm_1 = pickle.load(open('/home/jupyter/work/bgprophet/results/predict_v_lstm_1_2018-12-01.pkl'))

# %%
df_v_lstm_1.y_pred = df_v_lstm_1.y_pred.apply(lambda x:x[0])

# %%
df_v_lstm_1[:100].plot.line(figsize=(10,5))

# %%
df_conv_lstm_7 = pickle.load(open('/home/jupyter/work/bgprophet/results/predict_conv_lstm_7.pkl'))

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

sqrt(mean_squared_error(df_conv_lstm_7.y_pred, df_conv_lstm_7.y_true))
# Out:
# 23.723237767146156
